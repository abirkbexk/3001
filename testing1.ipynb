# %%
# !git clone https://github.com/abirkbexk/3001.git
# %cd /content/3001
# !ls
# Out:
# Cloning into '3001'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 27 (delta 5), reused 11 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 31.81 KiB | 6.36 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# /content/3001
#  examples	    'MyWorkshop 1.ipynb'   zheng_reflection.txt
# 'hellow world.txt'   Practical1.ipynb

# %%
# !git config user.name "Zheng Tew"
# !git config user.email "ztew0001@student.monash.edu"

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-b61ff4d8-b796-4718-90f3-f98eb7bb0ab6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b61ff4d8-b796-4718-90f3-f98eb7bb0ab6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !git checkout main
# !cp /content/testing1.ipynb /content/3001/
# !ls
# Out:
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# cp: cannot stat '/content/testing1.ipynb': No such file or directory
#  examples	    'MyWorkshop 1.ipynb'   zheng_reflection.txt
# 'hellow world.txt'   Practical1.ipynb
